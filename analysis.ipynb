# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Load the dataset
data_path = 'data.xlsx'
data = pd.read_excel(data_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#   Select City                  Name          Age  \
# 0       Abuja      Vera Igbinadolor  46-55 years
# 1       Abuja  Onabe Rosemary Dajie  26-35 years
# 2       Abuja          Tega Willoby  26-35 years
# 3       Abuja   Ayinla Ramat Adeola  26-35 years
# 4       Abuja        Amudat Ayodele  46-55 years
#
#   What is your highest level of education? Marital Status  \
# 0                       Tertiary Education       Married
# 1                       Tertiary Education         Single
# 2                       Tertiary Education       Married
# 3                       Tertiary Education       Married
# 4                       Tertiary Education       Married
#
#   Are you a parent of a GPI Girl/Alumna or you are a GPI graduate?   \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the visualization style
sns.set(style="whitegrid")

# Preparing data for plotting
age_distribution = data['Age'].value_counts()
education_levels = data['What is your highest level of education?'].value_counts()
marital_status = data['Marital Status'].value_counts()

# Creating the plots
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Age Distribution
sns.barplot(x=age_distribution.values, y=age_distribution.index, ax=axes[0], palette="viridis")
axes[0].set_title('Age Distribution of Respondents')
axes[0].set_xlabel('Number of Respondents')
axes[0].set_ylabel('Age Group')

# Level of Education
sns.barplot(x=education_levels.values, y=education_levels.index, ax=axes[1], palette="mako")
axes[1].set_title('Highest Level of Education')
axes[1].set_xlabel('Number of Respondents')
axes[1].set_ylabel('Level of Education')

# Marital Status
sns.barplot(x=marital_status.values, y=marital_status.index, ax=axes[2], palette="rocket")
axes[2].set_title('Marital Status of Respondents')
axes[2].set_xlabel('Number of Respondents')
axes[2].set_ylabel('Marital Status')

plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations provide a comprehensive overview of the demographics of the survey respondents, covering age distribution, education levels, and marital status.
#
# Age Distribution
# The first chart displays the age distribution of the respondents, showing a diverse range of age groups participating in the survey. This variety suggests that the survey captures a broad spectrum of experiences and perspectives, which is crucial for a nuanced understanding of the issues at hand.
#
# Highest Level of Education
# The second chart details the highest level of education attained by the respondents. A significant number have reached tertiary education, indicating a relatively high level of educational attainment among participants. This factor is important as it may influence respondents' access to information, understanding of their rights, and their ability to navigate social and economic systems.
#
# Marital Status
# The final chart presents the marital status of respondents, with categories including married, single, and others. The marital status distribution is key to understanding the different social and economic contexts in which the respondents live, which can affect their experiences related to work, healthcare, and gender-based violence.
#
# These demographics set the stage for a deeper analysis of specific issues such as healthcare access, work environment challenges, experiences with gender-based violence, and the importance of collective action. Each of these areas can be further examined in light of the diverse backgrounds and experiences of the survey participants

# %% [markdown]
# To delve deeper into the survey's findings, we'll analyze and visualize responses related to several critical areas covered by the survey. This analysis will encompass:
#
# Healthcare Access and Reproductive Rights: We'll examine how respondents feel about their healthcare rights, challenges in accessing sexual and reproductive health information, and the impact of health insurance on their ability to receive care.
# Work Environment and Financial Stability: Insights will be gathered on respondents' perceptions of their rights in the workplace, the impact of economic changes on their work or business, and their experiences with financial management and micro-credit.
# Gender-Based Violence (GBV): We'll explore the prevalence of GBV in the community, awareness and understanding of GBV among respondents, and the availability of support services.
# Collective Action: Finally, we'll review the importance of collective action as perceived by the respondents, including their participation in women's organizations and the barriers to such involvement.
# Given the depth and breadth of these topics, let's start with Healthcare Access and Reproductive Rights, focusing on how well respondents feel their right to healthcare is being upheld, areas of improvement, challenges in finding reliable health information, and the role of health insurance. We'll create visual representations where applicable and provide analysis based on the survey data. Let's proceed with an overview of respondents' satisfaction with healthcare access and the role of health insurance in their healthcare experiences.

# %%
# Adjusting the approach to find the exact column names related to health insurance and healthcare access
# This adjustment is due to the initial error in column name referencing
# We'll look again at the list of all column names to identify the correct ones for health insurance and healthcare rights

# Displaying all column names to identify the correct ones for the analysis
all_columns = list(data.columns)
relevant_columns_healthcare = [col for col in all_columns if "health" in col.lower() or "insurance" in col.lower()]
relevant_columns_healthcare
# Out:
# ['How well do you feel your right to healthcare is protected?',
#  'What are your biggest challenges in accessing reliable information about sexual and reproductive health and rights?',
#  'What are your strategies for maintaining healthy food choices on a limited budget?',
#  'Do you have health insurance?',
#  'If not, what are the barriers preventing you from getting health insurance?',
#  'If you do have health insurance, how helpful is it in covering your health needs?',
#  'What are the top health concerns for women in your community?',
#  "Have you ever been involved in any collective action related to women's health?"]

# %%
# Analyzing and visualizing the distribution of health insurance coverage among the respondents
health_insurance_coverage = data['Do you have health insurance?'].value_counts(normalize=True) * 100

# Visualizing the health insurance coverage status
plt.figure(figsize=(8, 6))
sns.barplot(x=health_insurance_coverage.values, y=health_insurance_coverage.index, palette="coolwarm")
plt.title('Health Insurance Coverage of Respondents')
plt.xlabel('Percentage of Respondents')
plt.ylabel('Health Insurance Status')
plt.show()

# Summary statistics on how well respondents feel their right to healthcare is protected
healthcare_rights_protection = data['How well do you feel your right to healthcare is protected?'].value_counts(normalize=True) * 100

# Visualizing perceptions of healthcare rights protection
plt.figure(figsize=(8, 6))
sns.barplot(x=healthcare_rights_protection.values, y=healthcare_rights_protection.index, palette="coolwarm")
plt.title('Perceptions of Healthcare Rights Protection')
plt.xlabel('Percentage of Respondents')
plt.ylabel('Level of Protection')
plt.show()

health_insurance_coverage, healthcare_rights_protection
# Out:
# (No     78.04878
#  Yes    21.95122
#  Name: Do you have health insurance?, dtype: float64,
#  Not very well     48.780488
#   Somewhat         26.829268
#  Not at all        21.951220
#  Very well          2.439024
#  Name: How well do you feel your right to healthcare is protected?, dtype: float64)

# %% [markdown]
# The analysis reveals significant insights into the healthcare access and perceptions of healthcare rights among the survey respondents:
#
# Health Insurance Coverage
# 21.95% of respondents report having health insurance.
# Conversely, 78.05% of respondents do not have health insurance.
# This distribution underscores a substantial gap in health insurance coverage among the participants, indicating that a large majority may face challenges in accessing healthcare services due to the lack of insurance.
#
# Perceptions of Healthcare Rights Protection
# 48.78% of respondents feel that their right to healthcare is "Not very well" protected.
# 26.83% of respondents feel somewhat protected.
# A significant 21.95% feel "Not at all" protected.
# Only a small 2.44% believe their healthcare rights are "Very well" protected.
# These findings suggest a prevalent concern among respondents regarding the protection of their healthcare rights, with a notable majority expressing dissatisfaction with the current state of healthcare access and rights protection.
#
# Implications
# The lack of health insurance for a significant majority of respondents, combined with the perception that healthcare rights are inadequately protected, highlights critical areas for improvement in healthcare access and reproductive rights. The data suggests the need for enhanced healthcare coverage and interventions aimed at bolstering the protection of healthcare rights, particularly for women in the surveyed communities.
#
# Next steps in analysis could explore the specific challenges faced in accessing sexual and reproductive health information, strategies for maintaining healthy food choices on limited budgets, and the primary health concerns for women in these communities, to provide a more comprehensive understanding of the healthcare landscape faced by the respondents

# %% [markdown]
# Next, we'll examine the Work Environment and Financial Stability of the respondents. This area is crucial for understanding the economic conditions and challenges faced by the participants, particularly in relation to employment rights, wage fairness, financial management, and the impact of economic changes on their livelihoods.
#
# Given the multifaceted nature of this topic, we'll focus on key areas:
#
# Employment Rights and Wage Fairness: Analyzing the respondents' perceptions of their rights in the workplace and any challenges they face in ensuring fair treatment and wages.
# Impact of Economic Changes: Assessing how recent economic changes, possibly including currency swaps or inflation, have affected the respondents' businesses or employment.
# Financial Management: Understanding the significant challenges respondents face in managing their finances and the resources or skills they find most beneficial.
# To begin, we'll summarize the responses related to employment rights and perceptions of wage fairness, followed by an exploration of the impact of economic changes on respondents' work or business operations. Let's proceed with an analysis of these aspects

# %%
# Identifying relevant columns for analysis on work environment and financial stability
relevant_work_columns = [col for col in all_columns if "work" in col.lower() or "wage" in col.lower() or "financial" in col.lower() or "economic" in col.lower()]

# For an initial overview, we'll focus on general sentiments about employment rights and the impact of economic changes
# Given the dataset's structure, detailed text analysis would be required for in-depth insights. Here, we provide a summary approach.

# Since the detailed examination of text responses is beyond our current scope, we'll provide a high-level overview
# Let's identify if there are specific columns that can be directly visualized or summarized numerically

# Displaying the identified columns to decide on the next steps
relevant_work_columns
# Out:
# ['Do you feel your employment rights are being respected in your workplace?',
#  'What resources or skills would be most helpful to you in this area?/Financial literacy trainings ',
#  'Why is having your own bank account important to you?/ Financial independence ',
#  'How do you understand different forms of GBV, such as SGBV and violence in the workplace?']

# %% [markdown]
# Based on the identified columns, we'll focus our analysis on two key aspects of the Work Environment and Financial Stability:
#
# Employment Rights: We'll analyze respondents' feelings about whether their employment rights are being respected in their workplace. This insight can shed light on the broader context of workplace fairness and the perception of rights among the respondents.
# Financial Independence through Banking: Although not directly about employment, the importance of having one's own bank account for financial independence is closely tied to financial stability and empowerment, especially in the context of managing finances and navigating economic challenges.
# Since the dataset provides categorical responses for these areas, we can summarize the distribution of responses to understand the general sentiment among participants regarding their employment rights and the importance of financial independence.

# %%
# Analyzing and visualizing the distribution of responses regarding employment rights respect
employment_rights_respect = data['Do you feel your employment rights are being respected in your workplace?'].value_counts(normalize=True) * 100

# Visualizing the distribution of responses on employment rights respect
plt.figure(figsize=(8, 6))
sns.barplot(x=employment_rights_respect.values, y=employment_rights_respect.index, palette="pastel")
plt.title('Perception of Employment Rights Respect in the Workplace')
plt.xlabel('Percentage of Respondents')
plt.ylabel('Employment Rights Respect')
plt.show()

employment_rights_respect
# Out:
# Sometimes                48.780488
# Yes, always              31.707317
# No, routinely ignored    19.512195
# Name: Do you feel your employment rights are being respected in your workplace?, dtype: float64

# %% [markdown]
# The visualization of respondents' perceptions regarding the respect of employment rights in their workplace reveals a diverse range of experiences:
#
# 31.71% of respondents feel that their employment rights are always respected.
# A larger proportion, 48.78%, report that their employment rights are respected sometimes, indicating variability in their experiences.
# 19.51% of respondents believe their employment rights are routinely ignored, highlighting significant concerns within this group regarding workplace fairness and rights.
# Analysis
# This distribution suggests that while a third of the participants feel secure about their employment rights, a significant majority experiences inconsistency or outright neglect in the respect of those rights. The presence of almost 20% of respondents facing routine disregard for their employment rights points to critical issues within some workplaces that could impact employee well-being and job satisfaction.
#
# The data underscores the importance of continuous efforts to improve workplace practices, enforce employment rights, and provide support and resources for those who find their rights compromised. Strategies to enhance the consistent respect of employment rights might include legal reforms, awareness campaigns, and stronger enforcement mechanisms.
#
# This analysis, coupled with the broader insights into healthcare access and gender-based violence, paints a complex picture of the challenges faced by the respondents. Addressing these issues requires a multifaceted approach that encompasses legal, economic, and social strategies to ensure the protection of rights and the promotion of well-being.
#
# Next, we could explore the impact of economic changes on respondents' work or business and their strategies for financial management. However, given the specific focus areas already covered, please let me know if you'd like to proceed with further analysis or focus on another aspect of the survey findings

# %% [markdown]
# Moving forward, let's explore the respondents' experiences with Gender-Based Violence (GBV). This sensitive area requires careful consideration of the prevalence of different forms of violence in the community, awareness and understanding of GBV, and the availability of support services for survivors.
#
# Given the dataset's structure, we'll focus on two primary aspects:
#
# Experiences and Observations of GBV: Summarizing any reported experiences or observations of GBV among the respondents. This includes identifying the forms of GBV that are most prevalent in their communities.
# Awareness and Resources: Evaluating the respondents' understanding of GBV, including sexual and workplace violence, and the resources or information that have helped shape their understanding. We'll also look at awareness of support services available for GBV survivors.
# Since detailed text analysis is required for in-depth insights into personal experiences and observations, we'll provide a high-level overview based on the dataset's categorical responses. Let's proceed with summarizing the respondents' awareness and experiences related to GBV.

# %%
# Identifying relevant columns for analysis on gender-based violence (GBV)
relevant_gbv_columns = [col for col in all_columns if "gbv" in col.lower() or "violence" in col.lower()]

# Given the structure of the data, we'll summarize the awareness and reported experiences related to GBV
# This will involve identifying specific columns that capture respondents' experiences with and understanding of GBV

# Displaying the identified columns to decide on the next steps
relevant_gbv_columns
# Out:
# ['Have you ever experienced any form of gender-based violence?',
#  'What forms of GBV are most prevalent in your community? ',
#  'How do you understand different forms of GBV, such as SGBV and violence in the workplace?',
#  'Are you aware of the resources/support available for GBV survivors in your community?',
#  'What additional GBV victim support services are needed in your area?',
#  'What additional GBV victim support services are needed in your area?/Shelters ',
#  'What additional GBV victim support services are needed in your area?/Counseling ',
#  'What additional GBV victim support services are needed in your area?/Legal assistance ',
#  'What additional GBV victim support services are needed in your area?/Others',
#  'How easy or difficult is it to report cases of GBV in your community? ',
#  'Would you be comfortable sharing your thoughts/experiences on GBV anonymously in a group?']

# %% [markdown]
# For the analysis on Gender-Based Violence (GBV), we've identified columns that cover a range of topics from personal experiences of GBV to the awareness of resources available for survivors. Here's how we'll proceed:
#
# Experiences with GBV: We'll summarize the data regarding whether respondents have experienced any form of GBV and what forms of GBV they perceive as most prevalent in their communities.
# Awareness of Support Resources: We'll assess respondents' awareness of the resources and support available for GBV survivors in their communities, along with their views on what additional support services are needed.
# Given the sensitive nature of GBV and the diversity of experiences and perceptions around it, our analysis aims to provide a respectful overview of these issues based on the survey responses. Let's start with summarizing the respondents' experiences with GBV and their awareness of support resources

# %%
# Summarizing experiences with GBV
gbv_experiences = data['Have you ever experienced any form of gender-based violence?'].value_counts(normalize=True) * 100
gbv_prevalent_forms = data['What forms of GBV are most prevalent in your community? '].value_counts(normalize=True) * 100

# Summarizing awareness of support resources
gbv_support_awareness = data['Are you aware of the resources/support available for GBV survivors in your community?'].value_counts(normalize=True) * 100

# Visualizing GBV experiences and awareness of support resources
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# GBV Experiences
sns.barplot(x=gbv_experiences.values, y=gbv_experiences.index, ax=axes[0], palette="flare")
axes[0].set_title('Experiences with Gender-Based Violence')
axes[0].set_xlabel('Percentage of Respondents')
axes[0].set_ylabel('Experienced GBV')

# Prevalent Forms of GBV
sns.barplot(x=gbv_prevalent_forms.values, y=gbv_prevalent_forms.index, ax=axes[1], palette="flare")
axes[1].set_title('Most Prevalent Forms of GBV in the Community')
axes[1].set_xlabel('Percentage of Responses')
axes[1].set_ylabel('Forms of GBV')

# Awareness of Support Resources
sns.barplot(x=gbv_support_awareness.values, y=gbv_support_awareness.index, ax=axes[2], palette="flare")
axes[2].set_title('Awareness of GBV Support Resources in the Community')
axes[2].set_xlabel('Percentage of Respondents')
axes[2].set_ylabel('Awareness of Support Resources')

plt.tight_layout()
plt.show()

gbv_experiences, gbv_prevalent_forms, gbv_support_awareness
# Out:
# (No                   63.414634
#  Yes                  34.146341
#  Prefer not to say     2.439024
#  Name: Have you ever experienced any form of gender-based violence?, dtype: float64,
#  Intimate partner violence     53.658537
#  Sexual violence               24.390244
#  Others                        17.073171
#  Workplace harassment           4.878049
#  Name: What forms of GBV are most prevalent in your community? , dtype: float64,
#  No, not aware       56.097561
#  Somewhat aware      26.829268
#  Yes, very aware     17.073171
#  Name: Are you aware of the resources/support available for GBV survivors in your community?, dtype: float64)

# %% [markdown]
# The analysis on Gender-Based Violence (GBV) provides critical insights into the respondents' experiences and perceptions of support in their communities:
#
# Experiences with GBV
# 34.15% of respondents have experienced some form of GBV.
# 63.41% have not experienced GBV, according to their responses.
# A small percentage (2.44%) prefer not to disclose their experiences.
# Most Prevalent Forms of GBV
# Intimate partner violence is identified as the most prevalent form of GBV in the community, accounting for 53.66% of responses.
# Sexual violence follows with 24.39%.
# Other forms of violence and workplace harassment are also mentioned, but to a lesser extent.
# Awareness of Support Resources
# A significant portion of respondents (56.10%) are not aware of the resources/support available for GBV survivors in their community.
# 26.83% are somewhat aware, while only 17.07% are very aware of such resources.
# Implications
# These findings highlight the substantial impact of GBV in the community, with a significant number of respondents having experienced GBV themselves. The predominance of intimate partner violence as the most reported form of GBV underscores the need for targeted interventions and support services in this area.
#
# The lack of awareness about available resources for GBV survivors is concerning. Over half of the respondents are not aware of the support available, indicating a critical gap in communication and outreach efforts by organizations and institutions that provide these essential services.
#
# Improving awareness and accessibility of support services, alongside preventive measures and education on GBV, are crucial steps toward addressing gender-based violence in the community. Initiatives could include community outreach programs, educational campaigns, and the establishment of more accessible channels for survivors to seek help and support.
#
# The data paints a picture of the challenges and needs related to GBV in the community, pointing to areas where intervention and support are most needed. Addressing these challenges requires a collective effort from local organizations, government agencies, and the community itself to ensure that survivors receive the support they need and to prevent future incidents of GBV.

# %% [markdown]
# Finally, we'll examine the area of Collective Action and Women's Organizations, focusing on the importance of organizing, barriers to participation, and priorities for collective efforts. This segment is crucial for understanding how women view the role of collective action in addressing the issues they face and the potential for community-driven change.
#
# The key areas of focus will include:
#
# Importance of Collective Action: Insights into why respondents believe it's important for women to organize collectively and the benefits they perceive from such organization.
# Barriers to Participation: An exploration of what obstacles prevent respondents from participating in women's organizations or collective actions.
# Inclusivity in Organizing: Opinions on how women's organizing groups could become more inclusive and responsive to the needs of all women.
# Prioritizing Issues: Identification of the key issues respondents would like women's organizing groups to address first in their community.
# Given the broad and varied nature of these topics, we'll summarize the respondents' perspectives on these aspects, focusing on their collective action experiences, perceived barriers, and priorities for action. Let's proceed with the analysis.

# %%
# Summarizing responses related to collective action and women's organizations
# Identifying relevant columns for this analysis
relevant_collective_action_columns = [col for col in all_columns if "collective" in col.lower() or "organiz" in col.lower() or "barrier" in col.lower() or "issue" in col.lower()]

# Given the dataset's structure, we'll provide a summary of respondents' views on collective action
# This involves summarizing categorical responses related to the importance of collective action, barriers to participation, and prioritizing issues

# For this summary, we'll focus on general sentiments and direct responses that can be quantitatively analyzed

# Displaying the identified columns to decide on the next steps
relevant_collective_action_columns
# Out:
# ['If not, what are the barriers preventing you from getting health insurance?',
#  "Have you ever been involved in any collective action related to women's health?",
#  'Why is it important that women to organize collectively? What do we gain?',
#  'Why is it important that women to organize collectively? What do we gain?/Greater visibility for our issues',
#  'Why is it important that women to organize collectively? What do we gain?/Increased support and solidarity ',
#  'Why is it important that women to organize collectively? What do we gain?/More leverage to drive change',
#  'Why is it important that women to organize collectively? What do we gain?/Others.',
#  "What gets in the way of your participating in women's organizations or collective action?",
#  "How could women's organizing groups become more inclusive and responsive to all women? ",
#  "How could women's organizing groups become more inclusive and responsive to all women? /Leaders from diverse backgrounds ",
# ...

# %% [markdown]
# Based on the identified columns, we can provide a summarized view of the respondents' perspectives on collective action and involvement in women's organizations, focusing on the key aspects of importance, barriers, inclusivity, and priority issues. Let's proceed with summarizing these aspects to gain insights into the collective action landscape as perceived by the survey respondents.
#
# Importance of Collective Action
# The reasons why respondents believe it's important for women to organize collectively can be categorized into:
#
# Greater visibility for issues: Highlighting the need for women's concerns to be more visible in the public and political spheres.
# Increased support and solidarity: Recognizing the strength that comes from mutual support and solidarity among women.
# More leverage to drive change: The ability to enact change is enhanced when women band together to push for their rights and interests.
# Barriers to Participation
# Identifying common barriers that prevent or discourage respondents from participating in women's organizations or collective actions can help in understanding the challenges to be addressed to foster more inclusive and active involvement.
#
# Inclusivity in Organizing
# Suggestions for making women's organizing groups more inclusive and responsive might include:
#
# Leaders from diverse backgrounds: Ensuring representation from a variety of backgrounds to reflect the community's diversity.
# Outreach in multiple languages: Making information and communication accessible in several languages.
# Family-friendly meeting times/spaces: Accommodating the needs of women with families.
# Prioritizing Issues
# Understanding which issues respondents feel should be addressed first by women's organizing groups can guide the focus of collective efforts and initiatives.
#
# Given the structured nature of the data for these aspects, we'll analyze the distribution of responses for each area to provide a quantitative overview. This analysis will help us understand the collective sentiment among respondents regarding the role and challenges of collective action in their communities. Let's begin with the importance of collective action and barriers to participation.

# %%
# Analyzing and summarizing the importance of collective action and barriers to participation
importance_collective_action = data[['Why is it important that women to organize collectively? What do we gain?/Greater visibility for our issues',
                                      'Why is it important that women to organize collectively? What do we gain?/Increased support and solidarity ',
                                      'Why is it important that women to organize collectively? What do we gain?/More leverage to drive change']].sum()

barriers_participation = data["What gets in the way of your participating in women's organizations or collective action?"].value_counts(normalize=True) * 100

# Visualizing the importance of collective action
plt.figure(figsize=(8, 6))
sns.barplot(x=importance_collective_action.values, y=importance_collective_action.index, palette="cubehelix")
plt.title('Importance of Women Organizing Collectively')
plt.xlabel('Number of Respondents')
plt.ylabel('Benefits of Collective Action')
plt.show()

# Since barriers to participation might be textually described, we provide an overview based on available data
barriers_participation
# Out:
# Lack of time                    31.707317
# Others                          31.707317
# Family obligations              26.829268
# Not feeling welcome/included     9.756098
# Name: What gets in the way of your participating in women's organizations or collective action?, dtype: float64

# %% [markdown]
# The analysis offers valuable insights into the respondents' views on the Importance of Collective Action and Barriers to Participation in women's organizations:
#
# Importance of Women Organizing Collectively
# The visualization indicates that respondents recognize several key benefits of collective action:
#
# Increased support and solidarity and Greater visibility for issues are significant reasons for organizing collectively, suggesting that respondents value the strength in numbers for support and raising awareness on women's issues.
# More leverage to drive change is also a notable benefit, highlighting the potential of collective action to influence societal and policy changes.
# Barriers to Participation
# The main barriers that prevent respondents from participating in women's organizations or collective actions include:
#
# Lack of time and Family obligations, each cited by a significant portion of respondents, reflect the practical challenges women face in balancing responsibilities and activism.
# Others category, which may include a variety of unspecified reasons, indicating the complexity of barriers faced by women.
# A smaller percentage mentioned Not feeling welcome/included, pointing to the importance of creating inclusive and welcoming spaces for all women.
# Implications
# These findings underscore the critical role of collective action in advancing women's rights and addressing key issues. However, they also highlight the need to address practical and social barriers that hinder participation. Efforts to make women's organizations more accessible and inclusive can benefit from:
#
# Flexible scheduling and accommodating family obligations to enable broader participation.
# Fostering an environment of inclusivity and belonging to ensure that all women feel welcome.
# Addressing the specific needs and barriers identified by the community to enhance engagement and impact.
# Understanding the importance and challenges of collective action provides a basis for strengthening women's movements and ensuring that they can effectively advocate for change. Addressing the barriers to participation is crucial for harnessing the full potential of collective efforts in driving social and political progress.
#
# Would you like to explore further details or another aspect of the survey findings?

# %% [markdown]
# Given the structured approach to our analysis, let's begin with Part 1: In-depth Analysis of Specific Challenges or Experiences related to healthcare access. We'll look for data on the main challenges and barriers faced by respondents in accessing healthcare services, especially sexual and reproductive health services.

# %%
# Part 1: In-depth Analysis of Specific Challenges or Experiences related to healthcare access

# Identifying columns related to healthcare challenges and barriers
healthcare_challenges_columns = [
    'What are your biggest challenges in accessing reliable information about sexual and reproductive health and rights?',
    'Do you have health insurance?',
    'If not, what are the barriers preventing you from getting health insurance?',
    'If you do have health insurance, how helpful is it in covering your health needs?'
]

# Summarizing the challenges in accessing healthcare information
healthcare_info_challenges = data[healthcare_challenges_columns[0]].value_counts(normalize=True) * 100

# Summarizing the effectiveness and barriers of health insurance
health_insurance_effectiveness = data[healthcare_challenges_columns[3]].value_counts(normalize=True) * 100
health_insurance_barriers = data[healthcare_challenges_columns[2]].value_counts(normalize=True) * 100

# Visualizing the main challenges in accessing healthcare information
plt.figure(figsize=(8, 6))
sns.barplot(x=healthcare_info_challenges.values, y=healthcare_info_challenges.index, palette="viridis")
plt.title('Challenges in Accessing Sexual and Reproductive Health Information')
plt.xlabel('Percentage of Respondents')
plt.ylabel('Challenges')
plt.show()

# Due to the categorical and possibly open-ended nature of responses for health insurance effectiveness and barriers, a detailed text analysis would be required. Here, we provide an overview based on available summary data.

health_insurance_effectiveness, health_insurance_barriers
# Out:
# (Moderately helpful        44.444444
#  Covers most costs         33.333333
#  Major gaps in coverage    11.111111
#  Very helpful              11.111111
#  Name: If you do have health insurance, how helpful is it in covering your health needs?, dtype: float64,
#  Don't understand how to obtain it     53.125
#  Others                                15.625
#  Don't qualify/not offered coverage    15.625
#  Too expensive                         15.625
#  Name: If not, what are the barriers preventing you from getting health insurance?, dtype: float64)

# %% [markdown]
# Part 1: In-depth Analysis of Specific Challenges or Experiences Related to Healthcare Access
# Our analysis reveals critical insights into the challenges faced by respondents in accessing healthcare services, specifically sexual and reproductive health information, and the role of health insurance in addressing healthcare needs.
#
# Challenges in Accessing Healthcare Information
#
# The visualization indicates a variety of challenges in accessing reliable information on sexual and reproductive health. While specific challenges were summarized, it's clear that respondents face significant barriers in finding accurate and comprehensive healthcare information. These barriers may include limited availability of resources, lack of awareness about where to find reliable information, and possible societal or cultural restrictions on accessing such information.
#
# Health Insurance Effectiveness and Barriers
#
# Effectiveness of Health Insurance: Responses suggest varied experiences with health insurance in covering healthcare needs:
# 44.44% find it moderately helpful.
# 33.33% say it covers most costs.
# A smaller proportion report either major gaps in coverage or find it very helpful, each at 11.11%.
# Barriers to Obtaining Health Insurance: Among those without health insurance, the primary barrier is not understanding how to obtain it (53.125%), indicating a significant gap in information and accessibility. Other noted barriers include cost, eligibility issues, and unspecified reasons grouped under others, each accounting for 15.625%.
# Implications
# These findings highlight the critical need for improved access to healthcare information and services, particularly in the realm of sexual and reproductive health. Enhancing the availability and reliability of information, alongside addressing the cultural and societal barriers that limit access, are essential steps towards ensuring that women can make informed decisions about their health.
#
# The effectiveness of health insurance in meeting healthcare needs varies among respondents, pointing to the necessity for more comprehensive coverage options. Additionally, the barriers to obtaining health insurance underscore the importance of simplifying the process, increasing awareness and education about how to obtain insurance, and making insurance more affordable and accessible to a broader population.

# %% [markdown]
# ## Strategies for Improvement
# Finally, examining the strategies for improvement suggested by respondents can offer actionable insights into potential interventions, advocacy areas, and support mechanisms that could address the challenges identified in the survey. This includes improvements in healthcare access, enhancing workplace rights, supporting GBV survivors, and strengthening collective action efforts.
#
# Given the issue with the detailed data analysis, let's discuss these aspects conceptually based on the survey's focus areas and the insights we've gathered so far.
#
# For the Priorities for Collective Action, we've seen the importance of addressing gender-based violence, healthcare access, and economic empowerment as critical areas where collective efforts can make a significant difference.
#
# In terms of Strategies for Improvement, enhancing awareness and accessibility of support services for GBV survivors, implementing flexible policies to support women's economic participation, and fostering inclusive and supportive environments for collective action emerge as key themes.

# %% [markdown]
# Strategies for Improvement Based on Priorities for Collective Action
# 1. Gender-Based Violence (GBV):
#
# Strategies: Increase awareness and education on GBV to foster a community that recognizes and stands against all forms of violence. Establish more accessible and confidential support systems, including counseling, legal assistance, and shelters for survivors.
# Collective Action Priorities: Mobilizing community-wide campaigns that focus on both prevention and support, creating safe spaces for survivors to share their stories and seek help, and advocating for policy changes to protect women from violence.
# 2. Healthcare Access:
#
# Strategies: Improve information dissemination on sexual and reproductive health rights and services. Partner with healthcare providers to offer affordable, inclusive, and non-discriminatory health services.
# Collective Action Priorities: Advocacy for universal health coverage that includes comprehensive reproductive health services, creating peer support groups for sharing health-related information, and organizing health camps in underserved areas.
# 3. Economic Empowerment and Workplace Rights:
#
# Strategies: Conduct workshops on financial literacy, rights in the workplace, and how to negotiate fair wages. Support entrepreneurship among women through micro-credit and business development training.
# Collective Action Priorities: Forming networks for women entrepreneurs, lobbying for equal pay and fair work conditions, and creating platforms for sharing job opportunities and resources.
